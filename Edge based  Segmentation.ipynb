# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\priya\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\priya\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2
import matplotlib.pyplot as plt
from skimage.io import imread
im = imread("C:\\Users\\PRIYA\\Pictures\\healthy path\\l17.jpg")
print(im.shape)
plt.figure()
plt.imshow(im)
plt.show()

img= cv2.imread("C:\\Users\\PRIYA\\Pictures\\healthy path\\l17.jpg",0)
#print(type(img))
#plt.imshow(img)

img1= cv2.Sobel(img,cv2.CV_64F,1,0,5)
img2= cv2.Sobel(img,cv2.CV_64F,0,1,5)
img3= cv2.Laplacian(img, cv2.CV_64F)
img4= cv2.Canny(img,100,150)

plt.subplot(2,3,1),plt.imshow(img,cmap="gray"),plt.title("Original Image")
plt.subplot(2,3,2),plt.imshow(img1,cmap="gray"),plt.title("Horizontal Sobel")
plt.subplot(2,3,3),plt.imshow(img2,cmap="gray"),plt.title("Vertical Sobel")
plt.subplot(2,3,4),plt.imshow(img3,cmap="gray"),plt.title("Laplacian")
plt.subplot(2,3,5),plt.imshow(img4,cmap="gray"),plt.title("Canny")
# Out:
# (406, 612, 3)
# (<AxesSubplot:title={'center':'Canny'}>,
#  <matplotlib.image.AxesImage at 0x1ef1420fa00>,
#  Text(0.5, 1.0, 'Canny'))
