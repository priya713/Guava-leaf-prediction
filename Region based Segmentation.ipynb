# %%
from matplotlib import pyplot as plt
# %matplotlib notebook
import numpy as npm skimage.io import imread,imsave

# %%
im = imread("C:\\Users\\PRIYA\\Pictures\\healthy path\\l17.jpg")
print(im.shape)

plt.figure()
plt.imshow(im)
plt.show()
# Out:
# (406, 612, 3)
# <img src="data:image/png;base64,..." width="640">

# %%
from skimage.filters import sobel,gaussian

im_ = gaussian(im, sigma=4)
br = sobel(im_[:,:,0])
bg = sobel(im_[:,:,1])
bb = sobel(im_[:,:,2])
brgb = br+bg+bb

plt.figure()
plt.imshow(brgb, cmap=plt.cm.gray)
plt.show()
# Out:
# C:\Users\PRIYA\anaconda3\lib\site-packages\skimage\_shared\utils.py:348: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   return func(*args, **kwargs)
# <img src="data:image/png;base64,..." width="640">

# %%
from skimage.feature import peak_local_max

markers = peak_local_max(brgb.max()-brgb)
plt.figure()
plt.imshow(im)
plt.plot(markers[:,1],markers[:,0],'b+')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
markers = peak_local_max(brgb.max()-brgb, threshold_rel=0.99, min_distance=50)

plt.figure()
plt.imshow(im)
plt.plot(markers[:,1],markers[:,0],'b+')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from skimage.filters import rank
from skimage.morphology import disk

im_ = gaussian(im, sigma=4)
gradr = rank.gradient(im_[:,:,0],disk(3)).astype('int')
gradg = rank.gradient(im_[:,:,1],disk(3)).astype('int')
gradb = rank.gradient(im_[:,:,2],disk(3)).astype('int')
grad = gradr+gradg+gradb

plt.figure()
plt.imshow(grad, cmap=plt.cm.gray)
plt.show()
# Out:
# C:\Users\PRIYA\AppData\Local\Temp\ipykernel_3552\1105767289.py:5: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   gradr = rank.gradient(im_[:,:,0],disk(3)).astype('int')
# C:\Users\PRIYA\AppData\Local\Temp\ipykernel_3552\1105767289.py:6: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   gradg = rank.gradient(im_[:,:,1],disk(3)).astype('int')
# C:\Users\PRIYA\AppData\Local\Temp\ipykernel_3552\1105767289.py:7: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   gradb = rank.gradient(im_[:,:,2],disk(3)).astype('int')
# <img src="data:image/png;base64,..." width="640">
